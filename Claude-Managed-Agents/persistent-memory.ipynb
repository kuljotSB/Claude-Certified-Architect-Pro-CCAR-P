# %% [markdown]
# ## Persistent Memory Store with Claude Managed Agents

# %% [markdown]
# ### Installing Utilities and Libraries

# %%
# %pip install anthropic==0.120.2 python-dotenv==1.2.2

# %% [markdown]
# ### Setting up the Environment

# %%
import os
from dotenv import load_dotenv

load_dotenv()

claude_model_name = os.getenv("CLAUDE_MODEL_NAME")
claude_api_key = os.getenv("CLAUDE_API_KEY")

# %% [markdown]
# ### Create the Anthropic Client

# %%
import anthropic

client = anthropic.Anthropic(api_key = claude_api_key)

# %% [markdown]
# ### Create the Memory Store

# %%
store = client.beta.memory_stores.create(
    name="User Profile",
    description="Persistent profile, preferences, and career information for the user.",
)
print(store.id)

# %% [markdown]
# ### Create Agent #1

# %%
agent_one = client.beta.agents.create(
    name="Memory-Agent-1",
    model=claude_model_name,
    system="You are a helpful AI Assistant.",
    tools=[
        {"type": "agent_toolset_20260401"},
    ],
)

print(f"Agent ID: {agent_one.id}, version: {agent_one.version}")

# %% [markdown]
# ### Create the Environment

# %%
environment = client.beta.environments.create(
    name="quickstart-env",
    config={
        "type": "cloud",
        "networking": {"type": "unrestricted"},
    },
)

print(f"Environment ID: {environment.id}")#

# %% [markdown]
# ### Create Session #1

# %%
session_one = client.beta.sessions.create(
    agent=agent_one.id,
    environment_id=environment.id,
    resources=[
        {
            "type": "memory_store",
            "memory_store_id": store.id,
            "access": "read_write",
            "instructions": "User preferences, memories and context. Check before starting any task.",
        }
    ],
)

# %% [markdown]
# ### Execute your Agent

# %%
with client.beta.sessions.events.stream(session_one.id) as stream:
            # Send the user message after the stream opens
            client.beta.sessions.events.send(
                session_one.id,
                events=[
                    {
                        "type": "user.message",
                        "content": [
                            {
                                "type": "text",
                                "text": """Please remember the following information about me for future conversations.

                                My name is Kuljot Singh Bakshi.

                                I am a Microsoft Certified Trainer (MCT).

                                I primarily create Microsoft Azure, AI, and Cybersecurity certification courses for Udemy.

                                My preferred programming language is Python.

                                When generating code examples, always prefer Python unless I explicitly request another language.

                                When writing technical explanations, keep them concise, practical, and hands-on.""",
                            },
                        ],
                    },
                ],
            )

            # Process streaming events
            for event in stream:
                match event.type:
                    case "agent.message":
                        for block in event.content:
                            print(block.text, end="")
                    case "agent.tool_use":
                        print(f"\n[Using tool: {event.name}]")
                    case "session.status_idle":
                        print("\n\nAgent finished.")
                        break

# %%
with client.beta.sessions.events.stream(session_one.id) as stream:
            # Send the user message after the stream opens
            client.beta.sessions.events.send(
                session_one.id,
                events=[
                    {
                        "type": "user.message",
                        "content": [
                            {
                                "type": "text",
                                "text": """Give me a sample REST API Implementation""",
                            },
                        ],
                    },
                ],
            )

            # Process streaming events
            for event in stream:
                match event.type:
                    case "agent.message":
                        for block in event.content:
                            print(block.text, end="")
                    case "agent.tool_use":
                        print(f"\n[Using tool: {event.name}]")
                    case "session.status_idle":
                        print("\n\nAgent finished.")
                        break

# %% [markdown]
# ### Create your Agent #2

# %%
agent_two = client.beta.agents.create(
    name="Memory-Agent-2",
    model=claude_model_name,
    system="You are a helpful AI Assistant.",
    tools=[
        {"type": "agent_toolset_20260401"},
    ],
)

print(f"Agent ID: {agent_two.id}, version: {agent_two.version}")

# %% [markdown]
# ### Create Session #2

# %%
session_two = client.beta.sessions.create(
    agent=agent_two.id,
    environment_id=environment.id,
    resources=[
        {
            "type": "memory_store",
            "memory_store_id": store.id,
            "access": "read_write",
            "instructions": "User preferences, memories and context. Check before starting any task.",
        }
    ],
)

# %% [markdown]
# ### Execute Agent #2

# %%
with client.beta.sessions.events.stream(session_two.id) as stream:
            # Send the user message after the stream opens
            client.beta.sessions.events.send(
                session_two.id,
                events=[
                    {
                        "type": "user.message",
                        "content": [
                            {
                                "type": "text",
                                "text": """Recommend my next Udemy Course""",
                            },
                        ],
                    },
                ],
            )

            # Process streaming events
            for event in stream:
                match event.type:
                    case "agent.message":
                        for block in event.content:
                            print(block.text, end="")
                    case "agent.tool_use":
                        print(f"\n[Using tool: {event.name}]")
                    case "session.status_idle":
                        print("\n\nAgent finished.")
                        break

# %%
with client.beta.sessions.events.stream(session_two.id) as stream:
            # Send the user message after the stream opens
            client.beta.sessions.events.send(
                session_two.id,
                events=[
                    {
                        "type": "user.message",
                        "content": [
                            {
                                "type": "text",
                                "text": """Please update my preferences.

I would now like all code examples to use C# by default instead of Python.""",
                            },
                        ],
                    },
                ],
            )

            # Process streaming events
            for event in stream:
                match event.type:
                    case "agent.message":
                        for block in event.content:
                            print(block.text, end="")
                    case "agent.tool_use":
                        print(f"\n[Using tool: {event.name}]")
                    case "session.status_idle":
                        print("\n\nAgent finished.")
                        break

# %%
with client.beta.sessions.events.stream(session_two.id) as stream:
            # Send the user message after the stream opens
            client.beta.sessions.events.send(
                session_two.id,
                events=[
                    {
                        "type": "user.message",
                        "content": [
                            {
                                "type": "text",
                                "text": """Generate a simple REST API example.""",
                            },
                        ],
                    },
                ],
            )

            # Process streaming events
            for event in stream:
                match event.type:
                    case "agent.message":
                        for block in event.content:
                            print(block.text, end="")
                    case "agent.tool_use":
                        print(f"\n[Using tool: {event.name}]")
                    case "session.status_idle":
                        print("\n\nAgent finished.")
                        break
